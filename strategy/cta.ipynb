# %%
import duckdb

db_path='../dataset/quant_data.duckdb'

con = duckdb.connect(db_path, read_only=True)
query = f"SELECT * FROM convertible_bonds"
df = con.execute(query).df()

df
# Out:
#       id update_date                                          data_hash  \
# 0      1  2025-08-13  bb289a689640955ca624a29f9208451935fbf4665fc440...
# 1      2  2025-08-13  bb289a689640955ca624a29f9208451935fbf4665fc440...
# 2      3  2025-08-13  bb289a689640955ca624a29f9208451935fbf4665fc440...
# 3      4  2025-08-13  bb289a689640955ca624a29f9208451935fbf4665fc440...
# 4      5  2025-08-13  bb289a689640955ca624a29f9208451935fbf4665fc440...
# ..   ...         ...                                                ...
# 482  483  2025-08-14  3d786a246584cbf6a56d01a93d9c4d599ebd3c6458561b...
# 483  484  2025-08-14  3d786a246584cbf6a56d01a93d9c4d599ebd3c6458561b...
# 484  485  2025-08-14  3d786a246584cbf6a56d01a93d9c4d599ebd3c6458561b...
# 485  486  2025-08-14  3d786a246584cbf6a56d01a93d9c4d599ebd3c6458561b...
# 486  487  2025-08-14  3d786a246584cbf6a56d01a93d9c4d599ebd3c6458561b...
#
#                  created_at                 updated_at bond_id bond_nm  \
# ...

# %%
df
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_3323/371099583.py in ?()
# ----> 1 df.order_by('price')
#
# ~/data/dataset/.venv/lib/python3.11/site-packages/pandas/core/generic.py in ?(self, name)
#    6314             and name not in self._accessors
#    6315             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6316         ):
#    6317             return self[name]
# -> 6318         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'order_by'

# %%
pip install duckdb
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.2/19.2 MB 1.2 MB/s eta 0:00:0000:0100:01
# ...
# Note: you may need to restart the kernel to use updated packages.
